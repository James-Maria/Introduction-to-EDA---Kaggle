# %% [markdown]
# ## Creating, Reading and Writing

# %% [markdown]
# #### Exercise

# %% [markdown]
# ## 1.
#
# In the cell below, create a DataFrame `fruits` that looks like this:
#
# ![](https://i.imgur.com/Ax3pp2A.png)

# %%
import pandas as pd

# %%
fruits = pd.DataFrame({'Apples': [30], 'Bananas':[21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# ## 2.
#
# Create a dataframe `fruit_sales` that matches the diagram below:
#
# ![](https://i.imgur.com/CHPn7ZF.png)

# %%
fruit_sales = pd.DataFrame({'Apples': [35,41], 'Bananas':[21,34]}, index = ['2017 Sales', '2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# ## 3.
#
# Create a variable `ingredients` with a Series that looks like:
#
# ```
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object
# ```

# %%
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index = ['Flour', 'Milk', 'Eggs', 'Spam'], name = 'Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ## 4.
#
# Read the following csv dataset of wine reviews into a DataFrame called `reviews`:
#
# ![](https://i.imgur.com/74RCZtU.png)
#
# The filepath to the csv file is `../input/wine-reviews/winemag-data_first150k.csv`. The first few lines look like:
#
# ```
# ,country,description,designation,points,price,province,region_1,region_2,variety,winery
# 0,US,"This tremendous 100% varietal wine[...]",Martha's Vineyard,96,235.0,California,Napa Valley,Napa,Cabernet Sauvignon,Heitz
# 1,Spain,"Ripe aromas of fig, blackberry and[...]",Carodorum Selección Especial Reserva,96,110.0,Northern Spain,Toro,,Tinta de Toro,Bodega Carmen Rodríguez
# ```

# %%
reviews = pd.read_csv(r'C:\Users\james\Downloads\Datasets\winemag-data_first150k.csv', index_col = 'Unnamed: 0')

# %% [markdown]
# ## 5.
#
# Run the cell below to create and display a DataFrame called `animals`:

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %% [markdown]
# In the cell below, write code to save this DataFrame to disk as a csv file with the name `cows_and_goats.csv`.

# %%
animals.to_csv('cows_and_goats.csv')

# %% [markdown]
# ## Indexing, Selecting & Assigning

# %%
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
reviews.country  # to access 'country' column alone
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %% [markdown]
# #### OR

# %%
reviews['country']
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews['country'][0]  # access 1st row from 'country' column
# Out:
# 'US'

# %%
# index-based selection

reviews.iloc[0]  # access 1st row
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                      235.0
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %%
reviews.iloc[:, 0]  # access 1st column
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
reviews.iloc[:3, 0]  # to access 1st 3 rows of 1st column
# Out:
# 0       US
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 0]  # access 2nd and 3rd rows of 1st column
# Out:
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0] # access 1st 3 rows of 1st column by passing  lsit
# Out:
# 0       US
# 1    Spain
# 2       US
# Name: country, dtype: object

# %%
reviews.iloc[-5:] # get the last five elements
# Out:
#        country                                        description  \
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
#        region_2          variety                 winery
# ...

# %%
reviews.loc[0, 'country'] # label-based selection
# Out:
# 'US'

# %%
reviews.loc[:, ['region_1', 'region_2', 'variety']]
# Out:
#                  region_1           region_2             variety
# 0             Napa Valley               Napa  Cabernet Sauvignon
# 1                    Toro                NaN       Tinta de Toro
# 2          Knights Valley             Sonoma     Sauvignon Blanc
# 3       Willamette Valley  Willamette Valley          Pinot Noir
# 4                  Bandol                NaN  Provence red blend
# ...                   ...                ...                 ...
# 150925  Fiano di Avellino                NaN         White Blend
# 150926          Champagne                NaN     Champagne Blend
# 150927  Fiano di Avellino                NaN         White Blend
# 150928          Champagne                NaN     Champagne Blend
# 150929         Alto Adige                NaN        Pinot Grigio
#
# [150930 rows x 3 columns]

# %% [markdown]
# #### Manipulating the index

# %%
reviews.set_index("variety")
# Out:
#                    country                                        description  \
# variety
# Cabernet Sauvignon      US  This tremendous 100% varietal wine hails from ...
# Tinta de Toro        Spain  Ripe aromas of fig, blackberry and cassis are ...
# Sauvignon Blanc         US  Mac Watson honors the memory of a wine once ma...
# Pinot Noir              US  This spent 20 months in 30% new French oak, an...
# Provence red blend  France  This is the top wine from La Bégude, named aft...
# ...                    ...                                                ...
# White Blend          Italy  Many people feel Fiano represents southern Ita...
# Champagne Blend     France  Offers an intriguing nose with ginger, lime an...
# White Blend          Italy  This classic example comes from a cru vineyard...
# Champagne Blend     France  A perfect salmon shade, with scents of peaches...
# Pinot Grigio         Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
# #### Conditional selection

# %%
reviews.country == 'Italy' # to check if each wine is Italian or not
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925     True
# 150926    False
# 150927     True
# 150928    False
# 150929     True
# Name: country, Length: 150930, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']  # to get rows where wine is Italian
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# ### OR

# %%
reviews[reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# ##### AND Operator

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]  # get Italian wines with at least 90 points
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# ##### OR Operator

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)] # get wine that's made in Italy or which is rated above 90
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# ##### Built-in Conditional Selectors

# %% [markdown]
# #### 1. isin()

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#        country                                        description  \
# 4       France  This is the top wine from La Bégude, named aft...
# 10       Italy  Elegance, complexity and structure come togeth...
# 13      France  This wine is in peak condition. The tannins an...
# 18      France  Coming from a seven-acre vineyard named after ...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                     designation  points  price            province  \
# 4                    La Brûlade      95   66.0            Provence
# ...

# %% [markdown]
# #### 2. isnull()

# %%
reviews.loc[reviews.price.isnull()]
# Out:
#             country                                        description  \
# 32            Italy  Underbrush, scorched earth, menthol and plum s...
# 56           France  Delicious while also young and textured, this ...
# 72            Italy  This offers aromas of red rose, wild berry, da...
# 82            Italy  Berry, baking spice, dried iris, mint and a hi...
# 116           Spain  Aromas of brandied cherry and crème de cassis ...
# ...             ...                                                ...
# 150377  New Zealand  Light and a bit herbal, like a pleasant St.-Jo...
# 150378  New Zealand  Impressive purple color, but less intense on t...
# 150587       Canada  Shows pronounced oily, earthy, almost tobacco-...
# 150673           US  Cherry-scented, clean and fruity. Good concent...
# 150922        Italy  Made by 30-ish Roberta Borghese high above Man...
#
#              designation  points  price            province  \
# ...

# %% [markdown]
# ### OR

# %%
reviews.loc[reviews.price.isna()]
# Out:
#             country                                        description  \
# 32            Italy  Underbrush, scorched earth, menthol and plum s...
# 56           France  Delicious while also young and textured, this ...
# 72            Italy  This offers aromas of red rose, wild berry, da...
# 82            Italy  Berry, baking spice, dried iris, mint and a hi...
# 116           Spain  Aromas of brandied cherry and crème de cassis ...
# ...             ...                                                ...
# 150377  New Zealand  Light and a bit herbal, like a pleasant St.-Jo...
# 150378  New Zealand  Impressive purple color, but less intense on t...
# 150587       Canada  Shows pronounced oily, earthy, almost tobacco-...
# 150673           US  Cherry-scented, clean and fruity. Good concent...
# 150922        Italy  Made by 30-ish Roberta Borghese high above Man...
#
#              designation  points  price            province  \
# ...

# %% [markdown]
# #### 3. notnull()

# %%
reviews.loc[reviews.price.notnull()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# ### OR

# %%
reviews.loc[reviews.price.notna()]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# #### Assigning data

# %%
reviews['critic'] = 'everyone'  # create a new column and assign constant value
reviews['critic']
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
#             ...
# 150925    everyone
# 150926    everyone
# 150927    everyone
# 150928    everyone
# 150929    everyone
# Name: critic, Length: 150930, dtype: object

# %%
reviews['index_backwards'] = range(len(reviews), 0, -1)  # with an iterable of values
reviews['index_backwards']
# Out:
# 0         150930
# 1         150929
# 2         150928
# 3         150927
# 4         150926
#            ...
# 150925         5
# 150926         4
# 150927         3
# 150928         2
# 150929         1
# Name: index_backwards, Length: 150930, dtype: int32

# %%
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# #### Exercise

# %% [markdown]
# ## 1.
#
# Select the `description` column from `reviews` and assign the result to the variable `desc`.

# %%
desc = reviews.description
desc
# Out:
# 0         This tremendous 100% varietal wine hails from ...
# 1         Ripe aromas of fig, blackberry and cassis are ...
# 2         Mac Watson honors the memory of a wine once ma...
# 3         This spent 20 months in 30% new French oak, an...
# 4         This is the top wine from La Bégude, named aft...
#                                 ...
# 150925    Many people feel Fiano represents southern Ita...
# 150926    Offers an intriguing nose with ginger, lime an...
# 150927    This classic example comes from a cru vineyard...
# 150928    A perfect salmon shade, with scents of peaches...
# 150929    More Pinot Grigios should taste like this. A r...
# Name: description, Length: 150930, dtype: object

# %% [markdown]
# ## 2.
#
# Select the first value from the description column of `reviews`, assigning it to variable `first_description`.

# %%
first_description = reviews.description.iloc[0]
first_description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %% [markdown]
# Note - While this is the preferred way to obtain the entry in the DataFrame, many other options will return a valid result, such as reviews.description.loc[0], reviews.description[0], and more!

# %% [markdown]
# ## 3.
#
# Select the first row of data (the first record) from `reviews`, assigning it to the variable `first_row`.

# %%
first_row = reviews.iloc[0]
first_row
# Out:
# country                                                           US
# description        This tremendous 100% varietal wine hails from ...
# designation                                        Martha's Vineyard
# points                                                            96
# price                                                          235.0
# province                                                  California
# region_1                                                 Napa Valley
# region_2                                                        Napa
# variety                                           Cabernet Sauvignon
# winery                                                         Heitz
# critic                                                      everyone
# index_backwards                                               150930
# Name: 0, dtype: object

# %% [markdown]
# ## 4.
#
# Select the first 10 values from the `description` column in `reviews`, assigning the result to variable `first_descriptions`.

# %%
first_descriptions = reviews.description.iloc[0:10]
first_descriptions
# Out:
# 0    This tremendous 100% varietal wine hails from ...
# 1    Ripe aromas of fig, blackberry and cassis are ...
# 2    Mac Watson honors the memory of a wine once ma...
# 3    This spent 20 months in 30% new French oak, an...
# 4    This is the top wine from La Bégude, named aft...
# 5    Deep, dense and pure from the opening bell, th...
# 6    Slightly gritty black-fruit aromas include a s...
# 7    Lush cedary black-fruit aromas are luxe and of...
# 8    This re-named vineyard was formerly bottled as...
# 9    The producer sources from two blocks of the vi...
# Name: description, dtype: object

# %% [markdown]
# #### OR

# %%
#first_descriptions = reviews.loc[:9, "description"]

# %% [markdown]
# ## 5.
#
# Select the records with index labels `1`, `2`, `3`, `5`, and `8`, assigning the result to the variable `sample_reviews`.
#
# In other words, generate the following DataFrame:
#
# ![](https://i.imgur.com/sHZvI1O.png)

# %%
sample_reviews = reviews.iloc[[1,2,3,5,8],:]
sample_reviews
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# ...

# %% [markdown]
# ## 6.
#
# Create a variable `df` containing the `country`, `province`, `region_1`, and `region_2` columns of the records with the index labels `0`, `1`, `10`, and `100`. In other words, generate the following DataFrame:
#
# ![](https://i.imgur.com/FUCGiKP.png)

# %%
df = reviews.loc[[0,1,10,100],['country', 'province', 'region_1', 'region_2']]
df
# Out:
#     country            province     region_1     region_2
# 0        US          California  Napa Valley         Napa
# 1     Spain      Northern Spain         Toro          NaN
# 10    Italy  Northeastern Italy       Collio          NaN
# 100      US          California  South Coast  South Coast

# %% [markdown]
# ## 7.
#
# Create a variable `df` containing the `country` and `variety` columns of the first 100 records.
#
# Hint: you may use `loc` or `iloc`. When working on the answer this question and the several of the ones that follow, keep the following "gotcha" described in the tutorial:
#
# > `iloc` uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.
# `loc`, meanwhile, indexes inclusively.
#
# > This is particularly confusing when the DataFrame index is a simple numerical list, e.g. `0,...,1000`. In this case `df.iloc[0:1000]` will return 1000 entries, while `df.loc[0:1000]` return 1001 of them! To get 1000 elements using `loc`, you will need to go one lower and ask for `df.iloc[0:999]`.

# %%
df = df = reviews.loc[0:99,['country', 'variety']]
df
# Out:
#    country               variety
# 0       US    Cabernet Sauvignon
# 1    Spain         Tinta de Toro
# 2       US       Sauvignon Blanc
# 3       US            Pinot Noir
# 4   France    Provence red blend
# ..     ...                   ...
# 95  France         Malbec-Merlot
# 96      US            Chardonnay
# 97      US    Cabernet Sauvignon
# 98  France         Merlot-Malbec
# 99  France  Ugni Blanc-Colombard
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 8.
#
# Create a DataFrame `italian_wines` containing reviews of wines made in `Italy`. Hint: `reviews.country` equals what?

# %%
italian_wines = reviews[reviews.country == 'Italy']
italian_wines
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# ...

# %% [markdown]
# ## 9.
#
# Create a DataFrame `top_oceania_wines` containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

# %%
top_oceania_wines = reviews[(reviews.points >= 95) & (reviews.country.isin(['New Zealand', 'Australia']))]
top_oceania_wines
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# ...

# %% [markdown]
# ### OR

# %%
top_oceania_wines = reviews[(reviews.points >= 95) & ((reviews.country == 'New Zealand') | (reviews.country == 'Australia'))]

# %%
top_oceania_wines
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# ...

# %% [markdown]
# Here, there is no row with country = 'New Zealand' and points > = 95

# %% [markdown]
# ## Summary Functions and Maps

# %% [markdown]
# #### Summary functions

# %%
reviews.price.describe()
# Out:
# count    137235.000000
# mean         33.131482
# std          36.322536
# min           4.000000
# 25%          16.000000
# 50%          24.000000
# 75%          40.000000
# max        2300.000000
# Name: price, dtype: float64

# %%
reviews.variety.describe()
# Out:
# count         150930
# unique           632
# top       Chardonnay
# freq           14482
# Name: variety, dtype: object

# %%
reviews.describe()
# Out:
#               points          price  index_backwards
# count  150930.000000  137235.000000    150930.000000
# mean       87.888418      33.131482     75465.500000
# std         3.222392      36.322536     43569.882402
# min        80.000000       4.000000         1.000000
# 25%        86.000000      16.000000     37733.250000
# 50%        88.000000      24.000000     75465.500000
# 75%        90.000000      40.000000    113197.750000
# max       100.000000    2300.000000    150930.000000

# %%
reviews.describe(include='all')
# Out:
#        country                                        description designation  \
# count   150925                                             150930      105195
# unique      48                                              97821       30621
# top         US  92-94 Barrel sample. A rounded wine, its tanni...     Reserve
# freq     62397                                                  6        2752
# mean       NaN                                                NaN         NaN
# std        NaN                                                NaN         NaN
# min        NaN                                                NaN         NaN
# 25%        NaN                                                NaN         NaN
# 50%        NaN                                                NaN         NaN
# 75%        NaN                                                NaN         NaN
# max        NaN                                                NaN         NaN
#
# ...

# %%
reviews.points.mean()  # mean of the points allotted
# Out:
# 87.8884184721394

# %%
reviews.variety.unique()  # list of unique values
# Out:
# array(['Cabernet Sauvignon', 'Tinta de Toro', 'Sauvignon Blanc',
#        'Pinot Noir', 'Provence red blend', 'Friulano', 'Tannat',
#        'Chardonnay', 'Tempranillo', 'Malbec', 'Rosé', 'Tempranillo Blend',
#        'Syrah', 'Mavrud', 'Sangiovese', 'Sparkling Blend',
#        'Rhône-style White Blend', 'Red Blend', 'Mencía', 'Palomino',
#        'Petite Sirah', 'Riesling', 'Cabernet Sauvignon-Syrah',
#        'Portuguese Red', 'Nebbiolo', 'Pinot Gris', 'Meritage', 'Baga',
#        'Glera', 'Malbec-Merlot', 'Merlot-Malbec', 'Ugni Blanc-Colombard',
#        'Viognier', 'Cabernet Sauvignon-Cabernet Franc', 'Moscato',
#        'Pinot Grigio', 'Cabernet Franc', 'White Blend', 'Monastrell',
#        'Gamay', 'Zinfandel', 'Greco', 'Barbera', 'Grenache',
#        'Rhône-style Red Blend', 'Albariño', 'Malvasia Bianca',
#        'Assyrtiko', 'Malagouzia', 'Carmenère', 'Bordeaux-style Red Blend',
#        'Touriga Nacional', 'Agiorgitiko', 'Picpoul', 'Godello',
# ...

# %%
reviews.variety.value_counts()  # list of unique values and how often they occur in the dataset
# Out:
# Chardonnay                  14482
# Pinot Noir                  14291
# Cabernet Sauvignon          12800
# Red Blend                   10062
# Bordeaux-style Red Blend     7347
#                             ...
# Früburgunder                    1
# Erbaluce                        1
# Malvazija                       1
# Chardonnay-Pinot Grigio         1
# Kuntra                          1
# Name: variety, Length: 632, dtype: int64

# %% [markdown]
# #### Maps

# %%
reviews.points
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
reviews.points.mean()
# Out:
# 87.8884184721394

# %%
reviews.points[0] - reviews.points.mean()
# Out:
# 8.111581527860594

# %%
reviews.points[4] - reviews.points.mean()
# Out:
# 7.111581527860594

# %%
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)
# Out:
# 0         8.111582
# 1         8.111582
# 2         8.111582
# 3         8.111582
# 4         7.111582
#             ...
# 150925    3.111582
# 150926    3.111582
# 150927    3.111582
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation    points  price  \
# 0                          Martha's Vineyard  8.111582  235.0
# ...

# %% [markdown]
# #### Exercises

# %% [markdown]
# ## 1.
#
# What is the median of the `points` column in the `reviews` DataFrame?

# %%
median_points = reviews.points.median()
median_points
# Out:
# 88.0

# %% [markdown]
# ## 2.
# What countries are represented in the dataset? (Your answer should not include any duplicates.)

# %%
countries = reviews.country.unique()
countries
# Out:
# array(['US', 'Spain', 'France', 'Italy', 'New Zealand', 'Bulgaria',
#        'Argentina', 'Australia', 'Portugal', 'Israel', 'South Africa',
#        'Greece', 'Chile', 'Morocco', 'Romania', 'Germany', 'Canada',
#        'Moldova', 'Hungary', 'Austria', 'Croatia', 'Slovenia', nan,
#        'India', 'Turkey', 'Macedonia', 'Lebanon', 'Serbia', 'Uruguay',
#        'Switzerland', 'Albania', 'Bosnia and Herzegovina', 'Brazil',
#        'Cyprus', 'Lithuania', 'Japan', 'China', 'South Korea', 'Ukraine',
#        'England', 'Mexico', 'Georgia', 'Montenegro', 'Luxembourg',
#        'Slovakia', 'Czech Republic', 'Egypt', 'Tunisia', 'US-France'],
#       dtype=object)

# %% [markdown]
# ## 3.
# How often does each country appear in the dataset? Create a Series `reviews_per_country` mapping countries to the count of reviews of wines from that country.

# %%
reviews_per_country = reviews.country.value_counts()
reviews_per_country
# Out:
# US                        62397
# Italy                     23478
# France                    21098
# Spain                      8268
# Chile                      5816
# Argentina                  5631
# Portugal                   5322
# Australia                  4957
# New Zealand                3320
# Austria                    3057
# Germany                    2452
# South Africa               2258
# Greece                      884
# Israel                      630
# Hungary                     231
# Canada                      196
# Romania                     139
# Slovenia                     94
# Uruguay                      92
# Croatia                      89
# Bulgaria                     77
# Moldova                      71
# Mexico                       63
# Turkey                       52
# Georgia                      43
# Lebanon                      37
# Cyprus                       31
# Brazil                       25
# Macedonia                    16
# ...

# %% [markdown]
# ## 4.
# Create variable `centered_price` containing a version of the `price` column with the mean price subtracted.
#
# (Note: this 'centering' transformation is a common preprocessing step before applying various machine learning algorithms.)

# %%
centered_price = reviews.price - reviews.price.mean()
centered_price
# Out:
# 0         201.868518
# 1          76.868518
# 2          56.868518
# 3          31.868518
# 4          32.868518
#              ...
# 150925    -13.131482
# 150926     -6.131482
# 150927    -13.131482
# 150928     18.868518
# 150929    -18.131482
# Name: price, Length: 150930, dtype: float64

# %% [markdown]
# ## 5.
# I'm an economical wine buyer. Which wine is the "best bargain"? Create a variable `bargain_wine` with the title of the wine with the highest points-to-price ratio in the dataset.

# %%
# To get all the wines with highest points-to-price ratio in the dataset

points_price = reviews.points / reviews.price

max_points_price = max(points_price)

index_max_points_price = points_price[points_price == max_points_price].index.values

bargain_wines = reviews.loc[index_max_points_price, 'variety']
bargain_wine = bargain_wines.unique()

# %%
bargain_wine
# Out:
# array(['Merlot', 'Pinot Grigio', 'Portuguese Red'], dtype=object)

# %%
# To get the 1st appearing wine with highest points-to-price ratio in the dataset

bargain_idx = (reviews.points / reviews.price).idxmax()
bargain_wine = reviews.loc[bargain_idx, 'variety']

# %%
bargain_wine
# Out:
# 'Merlot'

# %% [markdown]
# ## 6.
# There are only so many words you can use when describing a bottle of wine. Is a wine more likely to be "tropical" or "fruity"? Create a Series `descriptor_counts` counting how many times each of these two words appears in the `description` column in the dataset. (For simplicity, let's ignore the capitalized versions of these words.)

# %%
n_trop = reviews.description.map(lambda desc: "tropical" in desc).sum()
n_fruity = reviews.description.map(lambda desc: "fruity" in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])

# %%
descriptor_counts
# Out:
# tropical    4135
# fruity      8669
# dtype: int64

# %% [markdown]
# ## 7.
# We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
#
# Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
#
# Create a series `star_ratings` with the number of stars corresponding to each review in the dataset.

# %%
def ratings(df):
    if (df.country == 'Canada'):
        return 3
    elif (df.points >= 95):
        return 3
    elif (85 <= df.points < 95 ):
        return 2
    else:
        return 1

# %%
star_ratings = reviews.apply(ratings, axis='columns')

# %%
star_ratings
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 150925    2
# 150926    2
# 150927    2
# 150928    2
# 150929    2
# Length: 150930, dtype: int64

# %% [markdown]
# ## Grouping and Sorting

# %% [markdown]
# #### Exercises

# %% [markdown]
# ## 1.
# Create a `Series` whose index is the `designation` category from the dataset, and whose values count how many of each.

# %%
reviews.groupby('designation')['designation'].count()
# Out:
# designation
# "M"                    3
# #50 Mon Chou           1
# #SocialSecret          2
# '72                    1
# 'A Naca Rosso          1
#                       ..
# étoile Brut            1
# ía                     1
# ía Crianza             1
# Župska                 2
# ‘Rough Justice' Red    1
# Name: designation, Length: 30621, dtype: int64

# %% [markdown]
# ### OR

# %%
reviews.groupby('designation').size()
# Out:
# designation
# "M"                    3
# #50 Mon Chou           1
# #SocialSecret          2
# '72                    1
# 'A Naca Rosso          1
#                       ..
# étoile Brut            1
# ía                     1
# ía Crianza             1
# Župska                 2
# ‘Rough Justice' Red    1
# Length: 30621, dtype: int64

# %% [markdown]
# ## 2.
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending.

# %%
best_rating_per_price = reviews.groupby('price').points.agg(max)

# %%
best_rating_per_price
# Out:
# price
# 4.0        86
# 5.0        90
# 6.0        90
# 7.0        90
# 8.0        91
#          ...
# 1300.0     96
# 1400.0    100
# 1900.0     98
# 2013.0     91
# 2300.0     99
# Name: points, Length: 357, dtype: int64

# %% [markdown]
# ## 3.
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof.

# %%
price_extremes = reviews.groupby('variety').price.agg([min, max])

# %%
price_extremes
# Out:
#                          min    max
# variety
# Agiorgitiko              8.0   65.0
# Aglianico                6.0  130.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                   8.0   66.0
# ...                      ...    ...
# Zierfandler-Rotgipfler  20.0   25.0
# Zinfandel                4.0  100.0
# Zlahtina                13.0   17.0
# Zweigelt                 9.0   70.0
# Žilavka                 13.0   15.0
#
# [632 rows x 2 columns]

# %% [markdown]
# ## 4.
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sorted_varieties = price_extremes.sort_values(by = ['min', 'max'], ascending=False)

# %%
sorted_varieties
# Out:
#                                   min    max
# variety
# Cabernet-Shiraz                 150.0  150.0
# Mazuelo                          92.0  105.0
# Carignan-Syrah                   80.0   80.0
# Syrah-Cabernet Franc             69.0   69.0
# Nasco                            65.0   65.0
# ...                               ...    ...
# Rabigato                          NaN    NaN
# Sacy                              NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Terret Blanc                      NaN    NaN
# Zelen                             NaN    NaN
#
# [632 rows x 2 columns]

# %% [markdown]
# ### OR

# %%
price_extremes.sort_values(by = ['min'], ascending=False)
# Out:
#                                   min    max
# variety
# Cabernet-Shiraz                 150.0  150.0
# Mazuelo                          92.0  105.0
# Carignan-Syrah                   80.0   80.0
# Syrah-Cabernet Franc             69.0   69.0
# Nasco                            65.0   65.0
# ...                               ...    ...
# Rabigato                          NaN    NaN
# Sacy                              NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Terret Blanc                      NaN    NaN
# Zelen                             NaN    NaN
#
# [632 rows x 2 columns]

# %% [markdown]
# ## 5.
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: use `designation` and `points` columns.

# %%
reviewer_mean_ratings = reviews.groupby('designation').points.agg('mean')

# %%
reviewer_mean_ratings
# Out:
# designation
# "M"                    84.0
# #50 Mon Chou           88.0
# #SocialSecret          86.0
# '72                    87.0
# 'A Naca Rosso          88.0
#                        ...
# étoile Brut            90.0
# ía                     85.0
# ía Crianza             85.0
# Župska                 88.0
# ‘Rough Justice' Red    89.0
# Name: points, Length: 30621, dtype: float64

# %% [markdown]
# ## 6.
# What combination of countries and varieties are most common? Create a `Series` whose index is a `MultiIndex`of `{country, variety}` pairs. For example, a pinot noir produced in the US should map to `{"US", "Pinot Noir"}`. Sort the values in the `Series` in descending order based on wine count.

# %%
country_variety_counts = reviews.groupby(['country', 'variety']).variety.count().sort_values(ascending = False)

# %%
country_variety_counts
# Out:
# country      variety
# US           Pinot Noir                  10340
#              Cabernet Sauvignon           9178
#              Chardonnay                   8127
# France       Bordeaux-style Red Blend     4960
# US           Syrah                        4274
#                                          ...
# France       Pied de Perdrix                 1
# Tunisia      White Blend                     1
#              Rosé                            1
# Switzerland  White Blend                     1
# US           Carignan-Grenache               1
# Name: variety, Length: 1475, dtype: int64

# %% [markdown]
# ### OR

# %%
reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# Out:
# country      variety
# US           Pinot Noir                  10340
#              Cabernet Sauvignon           9178
#              Chardonnay                   8127
# France       Bordeaux-style Red Blend     4960
# US           Syrah                        4274
#                                          ...
# France       Pied de Perdrix                 1
# Tunisia      White Blend                     1
#              Rosé                            1
# Switzerland  White Blend                     1
# US           Carignan-Grenache               1
# Length: 1475, dtype: int64

# %% [markdown]
# ## Data Types and Missing Values

# %% [markdown]
# ## 1.
# What is the data type of the `points` column in the dataset?

# %%
dtype = reviews.points.dtype
dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 2.
# Create a Series from entries in the `points` column, but convert the entries to strings. Hint: strings are `str` in native Python.

# %%
point_strings = reviews.points.astype('str')
point_strings.dtype
# Out:
# dtype('O')

# %%
# dtype('o') --> object (or string)

# %% [markdown]
# ## 3.
# Sometimes the price column is null. How many reviews in the dataset are missing a price?

# %%
n_missing_prices = reviews.price.isnull().sum()
n_missing_prices
# Out:
# 13695

# %% [markdown]
# ## 4.
# What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the `region_1` field. This field is often missing data, so replace missing values with `Unknown`. Sort in descending order.  Your output should look something like this:
#
# ```
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
reviews_per_region = reviews['region_1'].fillna('Unknown').value_counts().sort_values(ascending = False)

# %%
reviews_per_region
# Out:
# Unknown                            25060
# Napa Valley                         6209
# Columbia Valley (WA)                4975
# Mendoza                             3586
# Russian River Valley                3571
#                                    ...
# Listrac                                1
# Civitella d'Agliano                    1
# Muscadet Sèvre et Maine Clisson        1
# Blanc Fumé de Pouilly                  1
# Stanislaus County                      1
# Name: region_1, Length: 1237, dtype: int64

# %% [markdown]
# ## Renaming and Combining

# %% [markdown]
# ## 1.
# `region_1` and `region_2` are pretty uninformative names for locale columns in the dataset. Create a copy of `reviews` with these columns renamed to `region` and `locale`, respectively.

# %%
renamed = reviews.rename(columns = {'region_1' : 'region', 'region_2' : 'locale'})
renamed
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# ## 2.
# Set the index name in the dataset to `wines`.

# %%
reindexed = reviews.rename_axis('wines', axis = 'rows')
reindexed
# Out:
#        country                                        description  \
# wines
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# wines
# 0                          Martha's Vineyard      96  235.0
# ...

# %% [markdown]
# ## 3.
# The [Things on Reddit](https://www.kaggle.com/residentmario/things-on-reddit/data) dataset includes product links from a selection of top-ranked forums ("subreddits") on reddit.com. Run the cell below to load a dataframe of products mentioned on the */r/gaming* subreddit and another dataframe for products mentioned on the *r//movies* subreddit.

# %%
gaming_products = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\Games.csv')
movie_products = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\MovieDetails.csv')

# %% [markdown]
# Create a `DataFrame` combining both dfs

# %%
combined_products = pd.concat([gaming_products, movie_products])

# %%
combined_products
# Out:
#                                                  name      category  \
# 0                 Mayflash Wireless Sensor DolphinBar   Electronics
# 1   Nintendo Entertainment System: NES Classic Edi...   Video Games
# 2                                      PlayStation TV   Video Games
# 3   Star Wars: The Old Republic – Knights of the E...   Video Games
# 4             Metal Gear Solid: The Legacy Collection   Video Games
# ..                                                ...           ...
# 2   Magic Makers - One Way Joker Forcing Red Back ...  Toys & Games
# 3                    SDCC 2015 SPACEBALLS Dark Helmet  Toys & Games
# 4                             The Sounds of Star Wars         Books
# 5                            Come with Me [CD-Single]   CDs & Vinyl
# 6                                         I Am Legend   Movies & TV
#
#                                           amazon_link  total_mentions  \
# 0   https://www.amazon.com/Mayflash-W010-Wireless-...              11
# ...

# %% [markdown]
# ## 4.
#
# Combine the datasets using join() function

# %%
gaming_products['index'] = list(range(0,210))
gaming_products.set_index('index',drop = True, inplace = True)
gaming_products
# Out:
#                                                     name     category  \
# index
# 0                    Mayflash Wireless Sensor DolphinBar  Electronics
# 1      Nintendo Entertainment System: NES Classic Edi...  Video Games
# 2                                         PlayStation TV  Video Games
# 3      Star Wars: The Old Republic – Knights of the E...  Video Games
# 4                Metal Gear Solid: The Legacy Collection  Video Games
# ...                                                  ...          ...
# 205                          Grey Goo [Online Game Code]  Video Games
# 206    The Dark Side of the Moon, 30th Anniversary Ed...  CDs & Vinyl
# 207                                            Severance        Books
# 208    Geplink 30 Meters(100 Feet) Active USB 2.0 Ext...  Electronics
# 209                                     A Microsoft Life        Books
#
#                                              amazon_link  total_mentions  \
# index
# ...

# %%
movie_products['index'] = list(range(0,7))
movie_products.set_index('index',drop = True, inplace = True)
movie_products
# Out:
#                                                     name      category  \
# index
# 0      Embodiment and the inner life: Cognition and C...         Books
# 1                                    The Art of Zootopia         Books
# 2      Magic Makers - One Way Joker Forcing Red Back ...  Toys & Games
# 3                       SDCC 2015 SPACEBALLS Dark Helmet  Toys & Games
# 4                                The Sounds of Star Wars         Books
# 5                               Come with Me [CD-Single]   CDs & Vinyl
# 6                                            I Am Legend   Movies & TV
#
#                                              amazon_link  total_mentions  \
# index
# 0          https://www.amazon.com/gp/product/0199226555/               2
# 1      https://www.amazon.com/Art-Zootopia-Jessica-Ju...               2
# 2      https://www.amazon.com/Magic-Makers-Joker-Forc...               1
# 3      https://www.amazon.com/SDCC-2015-SPACEBALLS-Da...               1
# ...

# %%
Join_products = gaming_products.join(movie_products, lsuffix = '_game', rsuffix = '_movie')

# %%
Join_products
# Out:
#                                                name_game category_game  \
# index
# 0                    Mayflash Wireless Sensor DolphinBar   Electronics
# 1      Nintendo Entertainment System: NES Classic Edi...   Video Games
# 2                                         PlayStation TV   Video Games
# 3      Star Wars: The Old Republic – Knights of the E...   Video Games
# 4                Metal Gear Solid: The Legacy Collection   Video Games
# ...                                                  ...           ...
# 205                          Grey Goo [Online Game Code]   Video Games
# 206    The Dark Side of the Moon, 30th Anniversary Ed...   CDs & Vinyl
# 207                                            Severance         Books
# 208    Geplink 30 Meters(100 Feet) Active USB 2.0 Ext...   Electronics
# 209                                     A Microsoft Life         Books
#
#                                         amazon_link_game  total_mentions_game  \
# index
# ...
