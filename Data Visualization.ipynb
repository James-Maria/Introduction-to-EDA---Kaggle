# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Seaborn

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ### Matplotlib

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
sns.get_dataset_names()  # list of all datasets available for plotting in Seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")  # to load 'tips' dataset from Seaborn

# %%
# get top 5 rows of the dataset

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(16,6))  # Set the width and height of the figure

sns.lineplot(data=tips)  # line chart showing the total bill for each order, corresponding tips paid and size of customers
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Line Charts

# %%
spotify_data = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\spotify.csv', index_col='Date', parse_dates=True)

# %% [markdown]
# index_col="Date" - When we load the dataset, we want each entry in the first column to denote a different row.
# To do this, we set the value of index_col to the name of the first column
# ("Date", found in cell A1 of the file when it's opened in Excel).
#
# parse_dates=True - This tells the notebook to understand the each row label as a date
# (as opposed to a number or other text with a different meaning).

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
plt.figure(figsize=(20,6))
plt.title("Daily Global Streams of Popular Songs in 2017-2018")  # Add title
sns.lineplot(data = spotify_data)
plt.show()

# %%
spotify_data.columns
# Out:
# Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.',
#        'Unforgettable'],
#       dtype='object')

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.ylabel('Shape of You vs Despacito')

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize = (35,15))
sns.barplot(x = spotify_data.head(26).index, y = spotify_data['Shape of You'].head(26))
plt.xticks(rotation = 45, fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Date', fontsize = 35)
plt.ylabel('Shape of You', fontsize = 35)
plt.title("Global Streams of 'Shape of You' song in January 2017", fontsize= 40)
plt.show()

# %% [markdown]
# ## Heatmap

# %%
candy_data = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\candy.csv', index_col='id')

# %%
candy_data
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(data = candy_data.iloc[:,10:13].head(20), annot = True, annot_kws={"size": 10}, fmt='.2f') 
# annot = True - to display the number on each box in the plot
# annot_kws={"size": 18} - increase size of annot
# fmt='.2f' - control decimal points in annot 
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
#plt.ylabel('Date', fontsize = 35)
plt.title("Sample Heatmap - Candy Data", fontsize= 20)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# Scatter plot showing the relationship between 'sugarpercent' and 'winpercent'

sns.scatterplot(x = candy_data['sugarpercent'], y = candy_data['winpercent'])
plt.title("Relationship between 'sugarpercent' and 'winpercent'", fontsize= 15)
plt.show()

# %% [markdown]
# The scatter plot does not show a strong correlation between the two variables. Since there is no clear relationship between the two variables, this tells us that sugar content does not play a strong role in candy popularity.

# %%
# Scatter plot w/ regression line showing the relationship between 'sugarpercent' and 'winpercent'

sns.regplot(x = candy_data['sugarpercent'], y = candy_data['winpercent'])
plt.title("Relationship between 'sugarpercent' and 'winpercent', with Regression Line", fontsize= 15)
plt.show()

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between 'winpercent' and 'sugarpercent'. Thus, people have a slight preference for candies containing relatively more sugar.

# %%
# Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate'

sns.scatterplot(x = candy_data['pricepercent'], y = candy_data['winpercent'], hue = candy_data['chocolate'])
plt.title("Relationship between 'pricepercent', 'winpercent', and 'chocolate'", fontsize= 15)
plt.show()

# %%
# Color-coded Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate' w/ regression lines

sns.lmplot(x = 'pricepercent', y = 'winpercent', hue = 'chocolate', data = candy_data)
plt.title("Relationship between 'pricepercent', 'winpercent', and 'chocolate' with Regression Line", fontsize= 12)
plt.show()

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper.
#
# One important note, however, is that the dataset is quite small -- so we shouldn't invest too much trust in these patterns! To inspire more confidence in the results, we should add more candies to the dataset.

# %%
# Scatter plot showing the relationship between 'chocolate' and 'winpercent'
# Note - Here, Chocolate column is a categorical column. Hence we use, swarmplot for plotting

sns.swarmplot(x = candy_data['chocolate'], y = candy_data['winpercent'])
plt.title("Relationship between 'chocolate' and 'winpercent'", fontsize= 12)
plt.show()

# %% [markdown]
# From all the above plots, chocolate candies tend to be more popular than candies without chocolate. Which plot is more appropriate to tell this story, lmplot or swarmplot?
#
# Ans - the categorical scatter plot (swarmplot) is the more appropriate plot.
#
# While both plots tell the desired story, the lmplot conveys far more information that could distract from the main point.

# %% [markdown]
# ## Histogram

# %%
cancer_data = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\cancer.csv', index_col = 'Id')

# %%
cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %% [markdown]
# Column ('Diagnosis') classifies tumors as either benign (which appears in the dataset as B) or malignant (M)

# %%
# In the first five rows of the data, what is the largest value for 'Perimeter (mean)'?
max_perim = max(cancer_data['Perimeter (mean)'].head())
max_perim
# Out:
# 87.46

# %%
# What is the value for 'Radius (mean)' for the tumor with Id 8510824?
mean_radius = cancer_data.loc[8510824][1]
mean_radius
# Out:
# 9.504

# %%
# Histograms for benign and maligant tumors
sns.histplot(x= cancer_data['Area (mean)'], hue = cancer_data['Diagnosis'])
plt.show()

# %% [markdown]
# Malignant tumors have higher values for 'Area (mean)', on average. Malignant tumors have a larger range of potential values.

# %% [markdown]
# ## KDE Plot

# %%
# KDE plots for benign and malignant tumors
sns.kdeplot(x= cancer_data['Radius (worst)'], hue = cancer_data['Diagnosis'])

plt.show()

# %% [markdown]
# Q. An algorithm that can diagnose tumors with high accuracy. Given a tumor with a value for 'Radius (worst)' of 25, do you think the algorithm is more likely to classify the tumor as benign or malignant?
#
# Ans - The algorithm is more likely to classify the tumor as malignant. This is because the curve for malignant tumors is much higher than the curve for benign tumors around a value of 25 -- and an algorithm that gets high accuracy is likely to make decisions based on this pattern in the data.

# %% [markdown]
# ### Styling with Seaborn

# %%
# Change the style of the figure
sns.set_style("dark")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
plt.title('Dark Theme', size = 15)

plt.show()

# %%
# Change the style of the figure
sns.set_style("darkgrid")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
plt.title('Darkgrid Theme', size = 15)

plt.show()

# %%
# Change the style of the figure
sns.set_style("whitegrid")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
plt.title('Whitegrid Theme', size = 15)

plt.show()

# %%
# Change the style of the figure
sns.set_style("white")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
plt.title('White Theme', size = 15)

plt.show()

# %%
# Change the style of the figure
sns.set_style("ticks")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
plt.title('Ticks Theme', size = 15)

plt.show()

# %% [markdown]
# ## Final Sum Up

# %%
my_data = pd.read_csv('C:\\Users\\james\\Downloads\\Datasets\\BigBasket Products.csv', index_col='index')

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#                                                  product  \
# index
# 1                 Garlic Oil - Vegetarian Capsule 500 mg
# 2                                  Water Bottle - Orange
# 3                         Brass Angle Deep - Plain, No.2
# 4      Cereal Flip Lid Container/Storage Jar - Assort...
# 5                     Creme Soft Soap - For Hands & Body
#
#                      category           sub_category              brand  \
# index
# 1            Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 2      Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 3        Cleaning & Household            Pooja Needs                Trm
# 4        Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 5            Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#        sale_price  market_price                      type  rating  \
# index
# 1           220.0         220.0          Hair Oil & Serum     4.1
# ...

# %%
# Scatter Plot

sns.scatterplot(x = my_data['sale_price'], y = my_data['market_price'], hue = my_data['category'])
# Out:
# <AxesSubplot:xlabel='sale_price', ylabel='market_price'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x = my_data['sale_price'].head(100), y = my_data['market_price'].head(100), hue = my_data['category'].head(100))
plt.title('Sales Price vs Market', size = 15)

plt.show()

# %%
# swarmplot

plt.figure(figsize=(35,15))
sns.swarmplot(x = my_data['category'].head(100), y = my_data['sale_price'].head(50), size = 15)
#plt.title('Sales Price vs Market', size = 15)
plt.xticks(fontsize = 20, rotation = 15)
plt.yticks(fontsize = 20)
plt.ylabel('Sales Price', fontsize = 25)
plt.xlabel('Category', fontsize = 25)
plt.show()
